# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.subplots_adjust(left=0.08, right=0.95, top=0.99, bottom=0.1, wspace=1.25,hspace=0.5)
x=np.array([1,2,3,4])
fig=plt.figure(1)
x = [1, 2, 3, 4, 5] 
y1 = [1, 4, 9, 16, 25] 
y2 = [1, 3, 5, 8, 15]
plt.subplot(211)
plt.plot(x, y1,'ro-') 
# plt.subplot(3, 4, 1) 
plt.subplot(212)
plt.plot(x, y2,'bD--')
plt.show()

plt.savefig('outputs.pdf')

# %%
from matplotlib import cm
import matplotlib.pyplot as plt 
import numpy as np
delta = 0.025 
x = y = np.arange(-3.0, 3.0, delta)
X, Y = np.meshgrid(x, y) 
Z1 = np.exp(-X**2 - Y**2) 
Z2 = np.exp(-(X - 1)**2 - (Y - 1)**2) 
Z = (Z1 - Z2) * 2
im = plt.imshow(Z, interpolation='bilinear',cmap=cm.RdYlGn,\
                origin='lower', extent=[-3, 3, -3, 3], \
                vmax=abs(Z).max(), vmin=-abs(Z).max())
plt.show()

# %%
fn ='./bonnor.txt' 
x,den,rds,pre=np.loadtxt(fn,unpack=True,usecols=[0,1,2,3])
fig=plt.figure(1,figsize=(7,4))

plt.subplot(121)
plt.xlim(0.1,100) 
plt.ylim(1.e-3,2)
plt.loglog(x,den) 
plt.xlabel(r'$\xi$') 
plt.ylabel(r'$\rho/\rho_0$')

plt.show()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# # 수업 중 예제

# %%
def a(k):
    return 2**k-1

for i in range(0,33,3):
    print("{:2d}   {:12d}|{:2d}    {:12d}|{:2d}   {:12d}".format(i,a(i),i+1,a(i+1),i+2,a(i+2)))
# Out:
#  0              0| 1               1| 2              3
#  3              7| 4              15| 5             31
#  6             63| 7             127| 8            255
#  9            511|10            1023|11           2047
# 12           4095|13            8191|14          16383
# 15          32767|16           65535|17         131071
# 18         262143|19          524287|20        1048575
# 21        2097151|22         4194303|23        8388607
# 24       16777215|25        33554431|26       67108863
# 27      134217727|28       268435455|29      536870911
# 30     1073741823|31      2147483647|32     4294967295

# %% [markdown]
# # 2020.03.25 수업 내용 실습

# %%
import matplotlib.pyplot as plt
import numpy as np

n=100
x0,x1 = 0.995,1.005


x = np.linspace(x0,x1, n)
y1 = (1-x)**6
y2 = 1 +15*x**2 + 15*x**4 
y3 = 6*x + 6*x**5 + 20*x**3

plt.plot(x,y1)
plt.plot(x,y2-y3, 'o')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import matplotlib.pyplot as plt
import numpy as np

for i in range(20):
    x = 10**i
    f = x*((x+1)**0.5-x**0.5)
    q = x/(np.sqrt(x+1)+np.sqrt(x))
    print('{:20d}     {:5g}   {:5g}'.format(x, f, q))
# Out:
#                    1     0.414214   0.414214
#                   10     1.54347   1.54347
#                  100     4.98756   4.98756
#                 1000     15.8074   15.8074
#                10000     49.9988   49.9988
#               100000     158.113   158.113
#              1000000       500     500
#             10000000     1581.14   1581.14
#            100000000      5000    5000
#           1000000000     15811.4   15811.4
#          10000000000     49999.9   50000
#         100000000000     158115   158114
#        1000000000000     500004   500000
#       10000000000000     1.57859e+06   1.58114e+06
#      100000000000000     5.02914e+06   5e+06
#     1000000000000000     1.86265e+07   1.58114e+07
#    10000000000000000         0   5e+07
#   100000000000000000         0   1.58114e+08
#  1000000000000000000         0   5e+08
# 10000000000000000000         0   1.58114e+09

# %%
x = np.arange(101)

s = 0
for i in range(100):
    s = s + x[i]

# %%
print(s)
# Out:
# 4950

# %% [markdown]
# # KAHAN

# %%
for i in range(100):
    xp = 0.1 - c
    sp = s
    s = s + xp
    c= (sp + xp) - sp) - xp

# %% [markdown]
# #  Khan Summation

# %%
def KahanSum(x,n):

# %%
x = 10
w = x
for i in range(10):
    w = (w +x/w)/2
    print(i,w)
print(np.sqrt(x))

# %% [markdown]
# # Bisection Method

# %%
import numpy as np
import matplotlib.pyplot as plt
'''
def func(x):
    f = pow(x, 6) - x - 1.

    return f
'''

def func(x):
    f = x + 10 - x*np.cosh(50/x)
    return f
  
    
func(126.63243603998862)
# Out:
# 0.0

# %%
a = 50
b = 128
eps = 10**-16
err = eps + 1
loop = 0 
while (err >= eps):  #epsilon
    loop += 1
    if (loop > 100): break
    fa = func(a)
    fb = func(b)
    c = (a+b)/2
    err = abs(c-a)
    fc = func(c)
    if loop % 4 ==0: print("계산중")
    if (fa*fc <= 0.):
        b = c
    else:
        a= c
    
print(c)
# Out:
# 계산중
# 계산중
# 계산중
# 계산중
# 계산중
# 계산중
# 계산중
# 계산중
# 계산중
# 계산중
# 계산중
# 계산중
# 계산중
# 계산중
# 계산중
# 계산중
# 계산중
# 계산중
# 계산중
# 계산중
# 계산중
# 계산중
# 계산중
# 계산중
# 계산중
# 126.63243603998868

# %%
x = np.linspace(50,200,1000)
f = x + 10 - x*np.cosh(50/x)

# plt.xlim(-1,1)
# plt.ylim(-1,0.1)
plt.plot(x,f)
plt.show()
